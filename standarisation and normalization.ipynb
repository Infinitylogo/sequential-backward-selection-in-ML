# %%
import pandas as pd

# %%
x=pd.read_csv('/home/rituraj/Downloads/Wine.csv',header=None)
x.columns=['Target','Alc','Malic_acid','Ash','Alc_ash','Mag','Total_phe','Flav','NonFlav_phe','Proa','Color_int','Hue','Diluted_wine','Proline']
print(x.head())
print(x.shape)
print('Number of samples=', x.shape[0])
print('Number of features=', x.shape[1]-1)
X=x.iloc[:,1:]
Y=x.iloc[:,0]

print('Number of classes=', Y.nunique())
print('Number of elements/classes=...')
print(Y.value_counts())
print('Number of missing values....')
print(x.isnull().sum())

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_std=sc.fit_transform(X)
print(x_std)

from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
x_norm=mms.fit_transform(X)
print(x_norm)

###############################train_test_split

print(x_norm.shape)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_norm, Y, test_size=0.05, random_state=1)

print(x_train.shape)
print(x_test.shape)
print(x_test)
# Out:
#    Target    Alc  Malic_acid   Ash  Alc_ash  Mag  Total_phe  Flav  \
# 0       1  14.23        1.71  2.43     15.6  127       2.80  3.06
# 1       1  13.20        1.78  2.14     11.2  100       2.65  2.76
# 2       1  13.16        2.36  2.67     18.6  101       2.80  3.24
# 3       1  14.37        1.95  2.50     16.8  113       3.85  3.49
# 4       1  13.24        2.59  2.87     21.0  118       2.80  2.69
#
#    NonFlav_phe  Proa  Color_int   Hue  Diluted_wine  Proline
# 0         0.28  2.29       5.64  1.04          3.92     1065
# 1         0.26  1.28       4.38  1.05          3.40     1050
# 2         0.30  2.81       5.68  1.03          3.17     1185
# 3         0.24  2.18       7.80  0.86          3.45     1480
# 4         0.39  1.82       4.32  1.04          2.93      735
# (178, 14)
# Number of samples= 178
# Number of features= 13
# Number of classes= 3
# Number of elements/classes=...
# 2    71
# 1    59
# 3    48
# Name: Target, dtype: int64
# Number of missing values....
# ...

# %%
import numpy as np
data=np.array([[0],[1],[2],[3],[4],[5]])
df3=pd.DataFrame(data, columns=['X'])
print(data)
####################Stand
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(data)
print(x)
#####################Normalization
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
y=mms.fit_transform(data)
print(y)
df1=pd.DataFrame(x, columns=['X_std'])
print(df1)
df2=pd.DataFrame(y, columns=['Normal'])
print(df2)

z=pd.concat([df3,df1,df2], axis=1)
print(z)
# Out:
# [[0]
#  [1]
#  [2]
#  [3]
#  [4]
#  [5]]
# [[-1.46385011]
#  [-0.87831007]
#  [-0.29277002]
#  [ 0.29277002]
#  [ 0.87831007]
#  [ 1.46385011]]
# [[0. ]
#  [0.2]
#  [0.4]
#  [0.6]
#  [0.8]
#  [1. ]]
#      X_std
# 0 -1.46385
# 1 -0.87831
# 2 -0.29277
# 3  0.29277
# 4  0.87831
# 5  1.46385
#    Normal
# 0     0.0
# 1     0.2
# 2     0.4
# 3     0.6
# 4     0.8
# 5     1.0
#    X    X_std  Normal
# 0  0 -1.46385     0.0
# 1  1 -0.87831     0.2
# 2  2 -0.29277     0.4
# 3  3  0.29277     0.6
# 4  4  0.87831     0.8
# 5  5  1.46385     1.0
# /home/rituraj/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /home/rituraj/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
